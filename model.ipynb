# %%
import numpy as np 
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import metrics

# %%
def unet(pretrained_weights = None,input_size = (None,None,1)):
    inputs = layers.Input(input_size)

    c1 = layers.Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (inputs)
    c1 = layers.Dropout(0.1) (c1)
    c1 = layers.Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
#    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = layers.MaxPooling2D((2, 2)) (c1)

    c2 = layers.Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = layers.Dropout(0.1) (c2)
    c2 = layers.Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
#    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = layers.MaxPooling2D((2, 2)) (c2)

    c3 = layers.Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = layers.Dropout(0.2) (c3)
    c3 = layers.Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
#    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = layers.MaxPooling2D((2, 2)) (c3)

    c4 = layers.Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = layers.Dropout(0.2) (c4)
    c4 = layers.Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
#    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = layers.MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = layers.Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = layers.Dropout(0.3) (c5)   
#    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)
    c5 = layers.Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)  

    u6 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = layers.Dropout(0.2) (c6)
#    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)
    c6 = layers.Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = layers.Dropout(0.2) (c7)
#    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)
    c7 = layers.Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = layers.Dropout(0.1) (c8)
#    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)
    c8 = layers.Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = layers.concatenate([u9, c1], axis=3)
    c9 = layers.Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = layers.Dropout(0.1) (c9)
#    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)
    c9 = layers.Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)
   

    outputs = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same') (c9)
    
    
    model = models.Model(inputs=[inputs], outputs=[outputs])

    model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = 'accuracy')
    model.summary()
    
    return model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

# %%
x_data = np.load(r'C:\Users\junha\Desktop\단층\reference\fault_images.npy')
y_data = np.load(r'C:\Users\junha\Desktop\단층\reference\fault_labels.npy')
X_train, X_test, Y_train, Y_test, = train_test_split(x_data, y_data, test_size=0.1, random_state=1121)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (468, 128, 128)
# (468, 128, 128)
# (52, 128, 128)
# (52, 128, 128)

# %%
nx=128
ny=128
model=unet(input_size=(nx,ny,1))

##training data
earlystopper = EarlyStopping(patience=10, verbose=1)
checkpointer = ModelCheckpoint('fault_model.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.3, batch_size=8, epochs=100, 
                   callbacks=[earlystopper, checkpointer])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 16)         160       ['input_2[0][0]']
#
#  dropout_9 (Dropout)         (None, 128, 128, 16)         0         ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_9[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 64, 64, 16)           0         ['conv2d_20[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 32)           4640      ['max_pooling2d_4[0][0]']
#
#  dropout_10 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_10[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 32)           0         ['conv2d_22[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 64)           18496     ['max_pooling2d_5[0][0]']
#
#  dropout_11 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 32, 32, 64)           36928     ['dropout_11[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 64)           0         ['conv2d_24[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 16, 16, 128)          73856     ['max_pooling2d_6[0][0]']
#
#  dropout_12 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 128)          147584    ['dropout_12[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 128)            0         ['conv2d_26[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 8, 8, 256)            295168    ['max_pooling2d_7[0][0]']
#
#  dropout_13 (Dropout)        (None, 8, 8, 256)            0         ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 8, 8, 256)            590080    ['dropout_13[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 16, 16, 128)          131200    ['conv2d_28[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 16, 16, 256)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 128)          295040    ['concatenate_4[0][0]']
#
#  dropout_14 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 128)          147584    ['dropout_14[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 32, 32, 64)           32832     ['conv2d_30[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 32, 32, 128)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 64)           73792     ['concatenate_5[0][0]']
#
#  dropout_15 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 64)           36928     ['dropout_15[0][0]']
#
#  conv2d_transpose_6 (Conv2D  (None, 64, 64, 32)           8224      ['conv2d_32[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 64, 64, 64)           0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_6[0][0]']
#
#  dropout_16 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_16[0][0]']
#
#  conv2d_transpose_7 (Conv2D  (None, 128, 128, 16)         2064      ['conv2d_34[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 128, 128, 32)         0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_7[0][0]']
#
#  dropout_17 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_17[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 1)          145       ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1940945 (7.40 MB)
# Trainable params: 1940945 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1602 - accuracy: 0.9600
# Epoch 1: val_loss improved from inf to 0.10671, saving model to fault_model.h5
# 41/41 [==============================] - 9s 160ms/step - loss: 0.1602 - accuracy: 0.9600 - val_loss: 0.1067 - val_accuracy: 0.9779
# Epoch 2/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9766
# Epoch 2: val_loss improved from 0.10671 to 0.09962, saving model to fault_model.h5
# 41/41 [==============================] - 6s 156ms/step - loss: 0.1114 - accuracy: 0.9766 - val_loss: 0.0996 - val_accuracy: 0.9779
# Epoch 3/100
# 41/41 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9766
# Epoch 3: val_loss improved from 0.09962 to 0.08986, saving model to fault_model.h5
# 41/41 [==============================] - 6s 158ms/step - loss: 0.1038 - accuracy: 0.9766 - val_loss: 0.0899 - val_accuracy: 0.9777
# Epoch 4/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0912 - accuracy: 0.9766
# Epoch 4: val_loss improved from 0.08986 to 0.07766, saving model to fault_model.h5
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0912 - accuracy: 0.9766 - val_loss: 0.0777 - val_accuracy: 0.9773
# Epoch 5/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9773
# Epoch 5: val_loss did not improve from 0.07766
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0783 - accuracy: 0.9773 - val_loss: 0.0805 - val_accuracy: 0.9792
# Epoch 6/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9783
# Epoch 6: val_loss improved from 0.07766 to 0.06845, saving model to fault_model.h5
# 41/41 [==============================] - 6s 155ms/step - loss: 0.0731 - accuracy: 0.9783 - val_loss: 0.0684 - val_accuracy: 0.9805
# Epoch 7/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9794
# Epoch 7: val_loss improved from 0.06845 to 0.06106, saving model to fault_model.h5
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0671 - accuracy: 0.9794 - val_loss: 0.0611 - val_accuracy: 0.9818
# Epoch 8/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9803
# Epoch 8: val_loss improved from 0.06106 to 0.05684, saving model to fault_model.h5
# 41/41 [==============================] - 6s 155ms/step - loss: 0.0628 - accuracy: 0.9803 - val_loss: 0.0568 - val_accuracy: 0.9822
# Epoch 9/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9810
# Epoch 9: val_loss improved from 0.05684 to 0.05656, saving model to fault_model.h5
# 41/41 [==============================] - 6s 157ms/step - loss: 0.0598 - accuracy: 0.9810 - val_loss: 0.0566 - val_accuracy: 0.9834
# Epoch 10/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9817
# Epoch 10: val_loss improved from 0.05656 to 0.05127, saving model to fault_model.h5
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0570 - accuracy: 0.9817 - val_loss: 0.0513 - val_accuracy: 0.9841
# Epoch 11/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9825
# Epoch 11: val_loss improved from 0.05127 to 0.05013, saving model to fault_model.h5
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0537 - accuracy: 0.9825 - val_loss: 0.0501 - val_accuracy: 0.9847
# Epoch 12/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0521 - accuracy: 0.9829
# Epoch 12: val_loss improved from 0.05013 to 0.04951, saving model to fault_model.h5
# 41/41 [==============================] - 6s 153ms/step - loss: 0.0521 - accuracy: 0.9829 - val_loss: 0.0495 - val_accuracy: 0.9848
# Epoch 13/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9835
# Epoch 13: val_loss improved from 0.04951 to 0.04892, saving model to fault_model.h5
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0499 - accuracy: 0.9835 - val_loss: 0.0489 - val_accuracy: 0.9853
# Epoch 14/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9842
# Epoch 14: val_loss improved from 0.04892 to 0.04776, saving model to fault_model.h5
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0475 - accuracy: 0.9842 - val_loss: 0.0478 - val_accuracy: 0.9854
# Epoch 15/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9844
# Epoch 15: val_loss did not improve from 0.04776
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0462 - accuracy: 0.9844 - val_loss: 0.0492 - val_accuracy: 0.9859
# Epoch 16/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9849
# Epoch 16: val_loss improved from 0.04776 to 0.04655, saving model to fault_model.h5
# 41/41 [==============================] - 6s 158ms/step - loss: 0.0448 - accuracy: 0.9849 - val_loss: 0.0466 - val_accuracy: 0.9858
# Epoch 17/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9852
# Epoch 17: val_loss improved from 0.04655 to 0.04655, saving model to fault_model.h5
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0428 - accuracy: 0.9852 - val_loss: 0.0465 - val_accuracy: 0.9860
# Epoch 18/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9857
# Epoch 18: val_loss improved from 0.04655 to 0.04514, saving model to fault_model.h5
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0414 - accuracy: 0.9857 - val_loss: 0.0451 - val_accuracy: 0.9866
# Epoch 19/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9862
# Epoch 19: val_loss did not improve from 0.04514
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.0459 - val_accuracy: 0.9868
# Epoch 20/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 0.9865
# Epoch 20: val_loss did not improve from 0.04514
# 41/41 [==============================] - 6s 153ms/step - loss: 0.0378 - accuracy: 0.9865 - val_loss: 0.0458 - val_accuracy: 0.9864
# Epoch 21/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9868
# Epoch 21: val_loss improved from 0.04514 to 0.04321, saving model to fault_model.h5
# 41/41 [==============================] - 6s 155ms/step - loss: 0.0366 - accuracy: 0.9868 - val_loss: 0.0432 - val_accuracy: 0.9872
# Epoch 22/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9873
# Epoch 22: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0345 - accuracy: 0.9873 - val_loss: 0.0436 - val_accuracy: 0.9875
# Epoch 23/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9875
# Epoch 23: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0331 - accuracy: 0.9875 - val_loss: 0.0484 - val_accuracy: 0.9873
# Epoch 24/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9878
# Epoch 24: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 151ms/step - loss: 0.0323 - accuracy: 0.9878 - val_loss: 0.0459 - val_accuracy: 0.9876
# Epoch 25/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0303 - accuracy: 0.9883
# Epoch 25: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0303 - accuracy: 0.9883 - val_loss: 0.0453 - val_accuracy: 0.9879
# Epoch 26/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9885
# Epoch 26: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0290 - accuracy: 0.9885 - val_loss: 0.0499 - val_accuracy: 0.9880
# Epoch 27/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9887
# Epoch 27: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 154ms/step - loss: 0.0283 - accuracy: 0.9887 - val_loss: 0.0502 - val_accuracy: 0.9880
# Epoch 28/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0273 - accuracy: 0.9890
# Epoch 28: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 153ms/step - loss: 0.0273 - accuracy: 0.9890 - val_loss: 0.0488 - val_accuracy: 0.9881
# Epoch 29/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9891
# Epoch 29: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 152ms/step - loss: 0.0268 - accuracy: 0.9891 - val_loss: 0.0504 - val_accuracy: 0.9879
# Epoch 30/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9897
# Epoch 30: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0249 - accuracy: 0.9897 - val_loss: 0.0516 - val_accuracy: 0.9884
# Epoch 31/100
# 41/41 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9898
# Epoch 31: val_loss did not improve from 0.04321
# 41/41 [==============================] - 6s 156ms/step - loss: 0.0250 - accuracy: 0.9898 - val_loss: 0.0520 - val_accuracy: 0.9882
# Epoch 31: early stopping

# %%
model=keras.models.load_model("fault_model.h5")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model=keras.models.load_model("fault_model.h5")
#
# File c:\Users\junha\AppData\Local\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\junha\AppData\Local\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\junha\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\lib\io\file_io.py:703, in is_directory_v2(path)
#     694 """Returns whether the path is a directory or not.
#     695
#     696 Args:
#    (...)
#     700   True, if the path is a directory; False otherwise
#     701 """
#     702 try:
# --> 703   return _pywrap_file_io.IsDirectory(compat.path_to_bytes(path))
#     704 except errors.OpError:
#     705   return False
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe8 in position 27: invalid continuation byte

# %%
preds_train=model.predict(X_train, verbose=1)
preds_test=model.predict(X_test, verbose=1)
# Out:
# 15/15 [==============================] - 2s 119ms/step
# 2/2 [==============================] - 0s 79ms/step

# %%
plt.imshow(preds_test[10],alpha =0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.imshow(X_train[100])
plt.imshow(preds_train[100],alpha =0.5)
plt.show()

plt.imshow(X_test[10])
plt.imshow(preds_test[10],alpha =0.5)
plt.show()

# %%
plt.imshow(X_train[200])
plt.imshow(preds_train[200],alpha =0.5)
plt.show()

plt.imshow(X_test[20])
plt.imshow(preds_test[20],alpha =0.5)
plt.show()

# %%
plt.subplot(1,2,1)
plt.imshow(preds_test[20])
plt.subplot(1,2,2)
plt.imshow(Y_test[20])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.subplot(1,2,1)
#       2 plt.imshow(preds_test[20])
#       3 plt.subplot(1,2,2)
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(X_train[300])
plt.imshow(preds_train[300],alpha =0.5)
plt.show()

plt.imshow(X_test[30])
plt.imshow(preds_test[30],alpha =0.5)
plt.show()

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

train_loss = results.history['loss']
train_acc = results.history['accuracy']
val_loss = results.history['val_loss']
val_acc = results.history['val_accuracy']

loss_ax.plot(train_loss, 'y', label="train loss")
loss_ax.plot(val_loss, 'r', label="val loss")
acc_ax.plot(train_acc, 'b', label='train accuracy')
acc_ax.plot(val_acc, 'g', label='val accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc = 'upper left')
acc_ax.legend(loc = 'lower left')

plt.show()
